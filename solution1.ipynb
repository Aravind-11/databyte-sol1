# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
x1=df['month_number']
y1=df['total_profit']
x2=df['facecream']
y2=df['total_profit']
y3=df['total_profit']
y4=df['total_profit']
y5=df['total_profit']
y6=df['total_profit']
y7=df['total_profit']
x3=df['facewash']
x4=df['toothpaste']
x5=df['bathingsoap']
x6=df['shampoo']
x7=df['moisturizer']

# %%
plt.plot(x2,y2,label='facecream')
plt.plot(x3,y2,label='facewash')
plt.plot(x4,y2,label='toothpaste')
plt.plot(x5,y2,label='bathingsoap')
plt.plot(x6,y2,label='shampoo')
plt.plot(x7,y2,label='moisturizer')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()
